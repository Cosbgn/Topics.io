# %%
import tweepy
import requests

# %% [markdown]
# # Flask APP - Twitter API

# %% [markdown]
# ### Authentication

# %%
consumer_key = '2thBDtK2JuxFZ6dvLgcpT49Md'
consumer_secret = 'OWCKKsKqiu0qk4Gww9PNbeJkzNS1VknqMRJZLcAqMxeqfqJzK2'
access_token = '2915229670-C0DdPbJZfyxIVpWa1TX9abByqyZ6Aw1iSnHCTJv'
access_token_secret = 'WJvJm5arNgi4YGAaIFeih4fIlBPGlmhtU11KLm4qE4Xrn'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# #### Test

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print tweet.text

# %% [markdown]
# ### Extract Tweets from Keyword

# %%
search_query = 'Refugees'

# %%
#### Query for Red 
red_query = 'https://api.twitter.com/1.1/search/tweets.json?q=trump%20lang%3Aen%20from%3Atheblaze%2C%20OR%20from%3Afoxnews%2C%20OR%20from%3Amaxnews&src=typd'
#### Query for Blue
blue_query = 'https://api.twitter.com/1.1/search/tweets.json?q=trump%20lang%3Aen%20from%3Atheblaze%2C%20OR%20from%3Afoxnews%2C%20OR%20from%3Amaxnews&src=typd'

# %%
r = requests.get(red_query)
r.status_code
# r.json(blue_query)
# Out:
# 400

# %%
api.search(q='dog')
# Out:
# [Status(contributors=None, truncated=False, text=u'RT @Normsmusic: Jezebel . com describes Trump Stately hot dog casing', is_quote_status=False, in_reply_to_status_id=None, id=786208564893417473, favorite_count=0, _api=<tweepy.api.API object at 0x104691f90>, author=User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 1096787952, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/777725528010817536/OFDajJd-_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 785, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'1096787952', u'profile_background_color': u'C0DEED'
# ...
